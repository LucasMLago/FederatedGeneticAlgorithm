# %%
import random
from typing import List, Tuple
import numpy as np

from deap import base, creator, tools, algorithms
from deap.tools import Logbook

# %%
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", np.ndarray, fitness=creator.FitnessMax)

# %%
toolbox = base.Toolbox()

# Attribute generator
toolbox.register("attr_bool", random.randint, 0, 1)

# Structure initializers
toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_bool, 100)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# %%
# Evaluation Function
def evalOneMax(individual):
    return (sum(individual),)

# %%
# Operators
toolbox.register("evaluate", evalOneMax)
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutFlipBit, indpb=0.05)
toolbox.register("select", tools.selTournament, tournsize=3)

# %%
def main():
    CROSSOVER_PROB = 0.5
    MUTATION_PROB = 0.2

    population = toolbox.population(n=300)

    # Evaluate the entire population
    fitnesses = list(map(toolbox.evaluate, population))
    for ind, fit in zip(population, fitnesses):
        ind.fitness.values = fit
    fits = [ind.fitness.values[0] for ind in population]
    generation = 0

    while max(fits) < 100 and generation < 1000:
        generation += 1
        print(f"--- Generation {generation} ---")
        offspring = toolbox.select(population, len(population))
        offspring = list(map(toolbox.clone, offspring))

        # Apply crossover on the offspring
        for child1, child2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < CROSSOVER_PROB:
                toolbox.mate(child1, child2)
                del child1.fitness.values
                del child2.fitness.values

        # Apply mutation on the offspring
        for mutant in offspring:
            if random.random() < MUTATION_PROB:
                toolbox.mutate(mutant)
                del mutant.fitness.values

        # Evaluate the individuals with an invalid fitness
        invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
        fitnesses = map(toolbox.evaluate, invalid_ind)
        for ind, fit in zip(invalid_ind, fitnesses):
            ind.fitness.values = fit
        
        population[:] = offspring

        # Gather all the fitnesses in one list and print the stats
        fits = [ind.fitness.values[0] for ind in population]
        mean = np.mean(fits)
        std = np.std(fits)
        min_fit = np.min(fits)
        max_fit = np.max(fits)

        print(f"  Min {min_fit}")
        print(f"  Max {max_fit}")
        print(f"  Avg {mean}")
        print(f"  Std {std}")

# %%
def GA() -> Tuple[List[creator.Individual], Logbook]:
    CROSSOVER_PROB = 0.5
    MUTATION_PROB = 0.2
    NUMBER_OF_GENERATIONS = 100

    population = toolbox.population(n=300)
    hof = tools.HallOfFame(1)

    stats = tools.Statistics(lambda ind: ind.fitness.values[0])
    stats.register("std", np.std)
    stats.register("avg", np.mean)
    stats.register("min", np.min)
    stats.register("max", np.max)

    population, log = algorithms.eaSimple(
        population,
        toolbox,
        cxpb=CROSSOVER_PROB,
        mutpb=MUTATION_PROB,
        ngen=NUMBER_OF_GENERATIONS,
        stats=stats,
        halloffame=hof,
        verbose=True
    )

    return population, log

# %%
pop, log = GA()
# Out:
# gen	nevals	std    	avg  	min	max
# 0  	300   	4.82242	50.47	34 	63
# 1  	187   	3.58268	54.38	46 	66
# 2  	191   	3.03238	57.4633	48 	67
# 3  	184   	3.10698	59.8   	52 	70
# 4  	158   	3.03844	62.3233	54 	71
# 5  	175   	2.95149	64.5733	54 	73
# 6  	176   	2.61201	66.8067	60 	74
# 7  	180   	2.74282	68.4833	59 	76
# 8  	194   	2.7243 	70.3133	63 	78
# 9  	174   	2.67016	72.06  	65 	80
# 10 	176   	2.66145	73.6633	65 	82
# 11 	172   	2.64381	75.3167	66 	83
# 12 	176   	2.92247	76.85  	68 	87
# 13 	180   	3.00384	78.6167	68 	88
# 14 	204   	2.89905	80.2867	71 	89
# 15 	177   	2.68584	82.14  	73 	90
# 16 	170   	2.66692	83.7533	73 	90
# 17 	176   	2.62356	85.06  	76 	91
# 18 	177   	2.28157	86.4333	78 	92
# 19 	172   	2.36835	87.53  	77 	94
# 20 	191   	2.62903	88.1867	77 	94
# 21 	188   	2.65452	89.3467	77 	95
# 22 	190   	2.42308	90.6967	81 	96
# 23 	194   	2.53832	91.6833	82 	97
# 24 	202   	2.48743	92.2933	83 	96
# 25 	168   	2.34278	93.2267	84 	97
# 26 	202   	2.3348 	93.9067	84 	97
# 27 	190   	2.21151	94.5767	83 	97
# 28 	166   	2.14984	95.3133	86 	98
# 29 	177   	2.48512	95.5867	83 	99
# 30 	197   	2.17193	96.2067	87 	99
# 31 	196   	2.04477	96.67  	88 	100
# 32 	175   	1.9511 	97.2233	88 	100
# 33 	193   	2.3078 	97.3067	89 	100
# 34 	184   	2.4485 	97.6467	88 	100
# 35 	176   	2.31052	98.1467	89 	100
# 36 	161   	2.11241	98.62  	89 	100
# 37 	186   	2.2488 	98.73  	90 	100
# 38 	193   	2.52132	98.64  	87 	100
# 39 	158   	2.05754	99.0567	91 	100
# 40 	201   	2.14678	98.9633	90 	100
# 41 	180   	2.41286	98.91  	89 	100
# 42 	171   	2.13755	99.03  	91 	100
# 43 	180   	2.59551	98.6633	89 	100
# 44 	161   	2.18872	99.0533	90 	100
# 45 	184   	2.23009	99.0067	90 	100
# 46 	178   	2.12445	98.9933	90 	100
# 47 	168   	2.25259	98.95  	90 	100
# 48 	177   	2.34781	98.9667	88 	100
# 49 	152   	2.33347	98.93  	88 	100
# 50 	180   	2.05375	99.11  	90 	100
# 51 	180   	2.22705	98.87  	91 	100
# 52 	185   	2.37851	98.8733	90 	100
# 53 	167   	2.12804	99.09  	88 	100
# 54 	198   	2.38196	98.86  	89 	100
# 55 	187   	2.08859	98.9333	91 	100
# 56 	179   	2.29656	98.85  	90 	100
# 57 	184   	2.18464	99.0633	88 	100
# 58 	192   	2.33732	98.94  	89 	100
# 59 	196   	2.27562	98.93  	89 	100
# 60 	165   	2.24881	99.0533	88 	100
# 61 	167   	2.07017	99.12  	89 	100
# 62 	179   	2.31679	98.95  	88 	100
# 63 	187   	2.35488	98.8233	88 	100
# 64 	184   	1.97804	99.1033	90 	100
# 65 	171   	2.2868 	99.0233	90 	100
# 66 	200   	2.24369	98.95  	88 	100
# 67 	195   	2.37364	98.95  	86 	100
# 68 	175   	2.1953 	98.8967	90 	100
# 69 	166   	2.20976	99.0167	89 	100
# 70 	199   	2.42839	98.77  	89 	100
# 71 	188   	2.05799	99.0367	91 	100
# 72 	177   	2.23661	98.97  	89 	100
# 73 	186   	2.38752	98.92  	89 	100
# 74 	175   	2.27718	98.9667	88 	100
# 75 	180   	2.35437	98.9167	89 	100
# 76 	187   	2.19457	98.8567	90 	100
# 77 	172   	2.29801	98.85  	91 	100
# 78 	220   	2.26159	98.8767	90 	100
# 79 	173   	2.39539	98.89  	87 	100
# 80 	179   	2.33137	98.8933	88 	100
# 81 	190   	1.97682	99.2133	90 	100
# 82 	174   	2.25758	98.9967	90 	100
# 83 	171   	2.15959	98.9467	90 	100
# 84 	188   	2.45266	98.6667	89 	100
# 85 	189   	2.27111	98.9067	89 	100
# 86 	193   	2.47768	98.7667	88 	100
# 87 	179   	2.12292	99.0567	90 	100
# 88 	178   	2.34903	98.9067	89 	100
# 89 	183   	2.38797	98.76  	89 	100
# 90 	201   	2.46271	98.78  	88 	100
# 91 	170   	2.02685	99.1233	91 	100
# 92 	173   	2.13072	99.0067	90 	100
# 93 	180   	2.07338	99.0333	88 	100
# 94 	195   	2.32594	98.8367	87 	100
# 95 	186   	2.45855	98.9533	87 	100
# 96 	166   	2.12041	99.0233	91 	100
# 97 	177   	1.81396	99.23  	92 	100
# 98 	194   	2.34782	98.88  	91 	100
# 99 	174   	2.05176	99.1833	90 	100
# 100	173   	2.20221	99.06  	90 	100

# %%
log
# Out:
# [{'gen': 0,
#   'nevals': 300,
#   'std': np.float64(4.822423318899604),
#   'avg': np.float64(50.47),
#   'min': np.float64(34.0),
#   'max': np.float64(63.0)},
#  {'gen': 1,
#   'nevals': 187,
#   'std': np.float64(3.5826805606975345),
#   'avg': np.float64(54.38),
#   'min': np.float64(46.0),
#   'max': np.float64(66.0)},
#  {'gen': 2,
#   'nevals': 191,
#   'std': np.float64(3.0323789707459428),
#   'avg': np.float64(57.46333333333333),
#   'min': np.float64(48.0),
#   'max': np.float64(67.0)},
#  {'gen': 3,
#   'nevals': 184,
#   'std': np.float64(3.106981386061612),
#   'avg': np.float64(59.8),
#   'min': np.float64(52.0),
#   'max': np.float64(70.0)},
#  {'gen': 4,
#   'nevals': 158,
#   'std': np.float64(3.038440755094992),
#   'avg': np.float64(62.32333333333333),
#   'min': np.float64(54.0),
#   'max': np.float64(71.0)},
#  {'gen': 5,
#   'nevals': 175,
#   'std': np.float64(2.9514892662669285),
#   'avg': np.float64(64.57333333333334),
#   'min': np.float64(54.0),
#   'max': np.float64(73.0)},
#  {'gen': 6,
#   'nevals': 176,
#   'std': np.float64(2.612014973583081),
#   'avg': np.float64(66.80666666666667),
#   'min': np.float64(60.0),
#   'max': np.float64(74.0)},
#  {'gen': 7,
#   'nevals': 180,
#   'std': np.float64(2.7428189068102102),
#   'avg': np.float64(68.48333333333333),
#   'min': np.float64(59.0),
#   'max': np.float64(76.0)},
#  {'gen': 8,
#   'nevals': 194,
#   'std': np.float64(2.7243021532536043),
#   'avg': np.float64(70.31333333333333),
#   'min': np.float64(63.0),
#   'max': np.float64(78.0)},
#  {'gen': 9,
#   'nevals': 174,
#   'std': np.float64(2.670156050371089),
#   'avg': np.float64(72.06),
#   'min': np.float64(65.0),
#   'max': np.float64(80.0)},
#  {'gen': 10,
#   'nevals': 176,
#   'std': np.float64(2.6614511496967634),
#   'avg': np.float64(73.66333333333333),
#   'min': np.float64(65.0),
#   'max': np.float64(82.0)},
#  {'gen': 11,
#   'nevals': 172,
#   'std': np.float64(2.6438082801561507),
#   'avg': np.float64(75.31666666666666),
#   'min': np.float64(66.0),
#   'max': np.float64(83.0)},
#  {'gen': 12,
#   'nevals': 176,
#   'std': np.float64(2.9224704161605013),
#   'avg': np.float64(76.85),
#   'min': np.float64(68.0),
#   'max': np.float64(87.0)},
#  {'gen': 13,
#   'nevals': 180,
#   'std': np.float64(3.00384013482002),
#   'avg': np.float64(78.61666666666666),
#   'min': np.float64(68.0),
#   'max': np.float64(88.0)},
#  {'gen': 14,
#   'nevals': 204,
#   'std': np.float64(2.899049652711883),
#   'avg': np.float64(80.28666666666666),
#   'min': np.float64(71.0),
#   'max': np.float64(89.0)},
#  {'gen': 15,
#   'nevals': 177,
#   'std': np.float64(2.6858394094460176),
#   'avg': np.float64(82.14),
#   'min': np.float64(73.0),
#   'max': np.float64(90.0)},
#  {'gen': 16,
#   'nevals': 170,
#   'std': np.float64(2.6669249874881915),
#   'avg': np.float64(83.75333333333333),
#   'min': np.float64(73.0),
#   'max': np.float64(90.0)},
#  {'gen': 17,
#   'nevals': 176,
#   'std': np.float64(2.623559922446344),
#   'avg': np.float64(85.06),
#   'min': np.float64(76.0),
#   'max': np.float64(91.0)},
#  {'gen': 18,
#   'nevals': 177,
#   'std': np.float64(2.281568661153014),
#   'avg': np.float64(86.43333333333334),
#   'min': np.float64(78.0),
#   'max': np.float64(92.0)},
#  {'gen': 19,
#   'nevals': 172,
#   'std': np.float64(2.368353858695951),
#   'avg': np.float64(87.53),
#   'min': np.float64(77.0),
#   'max': np.float64(94.0)},
#  {'gen': 20,
#   'nevals': 191,
#   'std': np.float64(2.6290344657729805),
#   'avg': np.float64(88.18666666666667),
#   'min': np.float64(77.0),
#   'max': np.float64(94.0)},
#  {'gen': 21,
#   'nevals': 188,
#   'std': np.float64(2.654522346654646),
#   'avg': np.float64(89.34666666666666),
#   'min': np.float64(77.0),
#   'max': np.float64(95.0)},
#  {'gen': 22,
#   'nevals': 190,
#   'std': np.float64(2.423081142310802),
#   'avg': np.float64(90.69666666666667),
#   'min': np.float64(81.0),
#   'max': np.float64(96.0)},
#  {'gen': 23,
#   'nevals': 194,
#   'std': np.float64(2.5383174654789644),
#   'avg': np.float64(91.68333333333334),
#   'min': np.float64(82.0),
#   'max': np.float64(97.0)},
#  {'gen': 24,
#   'nevals': 202,
#   'std': np.float64(2.487426157474607),
#   'avg': np.float64(92.29333333333334),
#   'min': np.float64(83.0),
#   'max': np.float64(96.0)},
#  {'gen': 25,
#   'nevals': 168,
#   'std': np.float64(2.3427808737101774),
#   'avg': np.float64(93.22666666666667),
#   'min': np.float64(84.0),
#   'max': np.float64(97.0)},
#  {'gen': 26,
#   'nevals': 202,
#   'std': np.float64(2.334799539337133),
#   'avg': np.float64(93.90666666666667),
#   'min': np.float64(84.0),
#   'max': np.float64(97.0)},
#  {'gen': 27,
#   'nevals': 190,
#   'std': np.float64(2.2115128054996402),
#   'avg': np.float64(94.57666666666667),
#   'min': np.float64(83.0),
#   'max': np.float64(97.0)},
#  {'gen': 28,
#   'nevals': 166,
#   'std': np.float64(2.149842371482668),
#   'avg': np.float64(95.31333333333333),
#   'min': np.float64(86.0),
#   'max': np.float64(98.0)},
#  {'gen': 29,
#   'nevals': 177,
#   'std': np.float64(2.4851201625318287),
#   'avg': np.float64(95.58666666666667),
#   'min': np.float64(83.0),
#   'max': np.float64(99.0)},
#  {'gen': 30,
#   'nevals': 197,
#   'std': np.float64(2.17193206359888),
#   'avg': np.float64(96.20666666666666),
#   'min': np.float64(87.0),
#   'max': np.float64(99.0)},
#  {'gen': 31,
#   'nevals': 196,
#   'std': np.float64(2.044773826123564),
#   'avg': np.float64(96.67),
#   'min': np.float64(88.0),
#   'max': np.float64(100.0)},
#  {'gen': 32,
#   'nevals': 175,
#   'std': np.float64(1.9510994051787542),
#   'avg': np.float64(97.22333333333333),
#   'min': np.float64(88.0),
#   'max': np.float64(100.0)},
#  {'gen': 33,
#   'nevals': 193,
#   'std': np.float64(2.3078031882193843),
#   'avg': np.float64(97.30666666666667),
#   'min': np.float64(89.0),
#   'max': np.float64(100.0)},
#  {'gen': 34,
#   'nevals': 184,
#   'std': np.float64(2.448500675016357),
#   'avg': np.float64(97.64666666666666),
#   'min': np.float64(88.0),
#   'max': np.float64(100.0)},
#  {'gen': 35,
#   'nevals': 176,
#   'std': np.float64(2.3105170176583614),
#   'avg': np.float64(98.14666666666666),
#   'min': np.float64(89.0),
#   'max': np.float64(100.0)},
#  {'gen': 36,
#   'nevals': 161,
#   'std': np.float64(2.112407788914505),
#   'avg': np.float64(98.62),
#   'min': np.float64(89.0),
#   'max': np.float64(100.0)},
#  {'gen': 37,
#   'nevals': 186,
#   'std': np.float64(2.248799679829219),
#   'avg': np.float64(98.73),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)},
#  {'gen': 38,
#   'nevals': 193,
#   'std': np.float64(2.5213224043478983),
#   'avg': np.float64(98.64),
#   'min': np.float64(87.0),
#   'max': np.float64(100.0)},
#  {'gen': 39,
#   'nevals': 158,
#   'std': np.float64(2.0575362829256636),
#   'avg': np.float64(99.05666666666667),
#   'min': np.float64(91.0),
#   'max': np.float64(100.0)},
#  {'gen': 40,
#   'nevals': 201,
#   'std': np.float64(2.1467779474262247),
#   'avg': np.float64(98.96333333333334),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)},
#  {'gen': 41,
#   'nevals': 180,
#   'std': np.float64(2.412861371898518),
#   'avg': np.float64(98.91),
#   'min': np.float64(89.0),
#   'max': np.float64(100.0)},
#  {'gen': 42,
#   'nevals': 171,
#   'std': np.float64(2.1375453211569577),
#   'avg': np.float64(99.03),
#   'min': np.float64(91.0),
#   'max': np.float64(100.0)},
#  {'gen': 43,
#   'nevals': 180,
#   'std': np.float64(2.5955068012924865),
#   'avg': np.float64(98.66333333333333),
#   'min': np.float64(89.0),
#   'max': np.float64(100.0)},
#  {'gen': 44,
#   'nevals': 161,
#   'std': np.float64(2.188718549491663),
#   'avg': np.float64(99.05333333333333),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)},
#  {'gen': 45,
#   'nevals': 184,
#   'std': np.float64(2.230087193113509),
#   'avg': np.float64(99.00666666666666),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)},
#  {'gen': 46,
#   'nevals': 178,
#   'std': np.float64(2.1244502556870772),
#   'avg': np.float64(98.99333333333334),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)},
#  {'gen': 47,
#   'nevals': 168,
#   'std': np.float64(2.25259110063648),
#   'avg': np.float64(98.95),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)},
#  {'gen': 48,
#   'nevals': 177,
#   'std': np.float64(2.3478122203920444),
#   'avg': np.float64(98.96666666666667),
#   'min': np.float64(88.0),
#   'max': np.float64(100.0)},
#  {'gen': 49,
#   'nevals': 152,
#   'std': np.float64(2.3334738052954442),
#   'avg': np.float64(98.93),
#   'min': np.float64(88.0),
#   'max': np.float64(100.0)},
#  {'gen': 50,
#   'nevals': 180,
#   'std': np.float64(2.053752662810203),
#   'avg': np.float64(99.11),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)},
#  {'gen': 51,
#   'nevals': 180,
#   'std': np.float64(2.227053359636151),
#   'avg': np.float64(98.87),
#   'min': np.float64(91.0),
#   'max': np.float64(100.0)},
#  {'gen': 52,
#   'nevals': 185,
#   'std': np.float64(2.3785055999280074),
#   'avg': np.float64(98.87333333333333),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)},
#  {'gen': 53,
#   'nevals': 167,
#   'std': np.float64(2.1280429193666808),
#   'avg': np.float64(99.09),
#   'min': np.float64(88.0),
#   'max': np.float64(100.0)},
#  {'gen': 54,
#   'nevals': 198,
#   'std': np.float64(2.3819599772736177),
#   'avg': np.float64(98.86),
#   'min': np.float64(89.0),
#   'max': np.float64(100.0)},
#  {'gen': 55,
#   'nevals': 187,
#   'std': np.float64(2.0885933597094057),
#   'avg': np.float64(98.93333333333334),
#   'min': np.float64(91.0),
#   'max': np.float64(100.0)},
#  {'gen': 56,
#   'nevals': 179,
#   'std': np.float64(2.2965553915955668),
#   'avg': np.float64(98.85),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)},
#  {'gen': 57,
#   'nevals': 184,
#   'std': np.float64(2.1846408298746858),
#   'avg': np.float64(99.06333333333333),
#   'min': np.float64(88.0),
#   'max': np.float64(100.0)},
#  {'gen': 58,
#   'nevals': 192,
#   'std': np.float64(2.337320403082698),
#   'avg': np.float64(98.94),
#   'min': np.float64(89.0),
#   'max': np.float64(100.0)},
#  {'gen': 59,
#   'nevals': 196,
#   'std': np.float64(2.2756171324133887),
#   'avg': np.float64(98.93),
#   'min': np.float64(89.0),
#   'max': np.float64(100.0)},
#  {'gen': 60,
#   'nevals': 165,
#   'std': np.float64(2.248812032063942),
#   'avg': np.float64(99.05333333333333),
#   'min': np.float64(88.0),
#   'max': np.float64(100.0)},
#  {'gen': 61,
#   'nevals': 167,
#   'std': np.float64(2.070169075220669),
#   'avg': np.float64(99.12),
#   'min': np.float64(89.0),
#   'max': np.float64(100.0)},
#  {'gen': 62,
#   'nevals': 179,
#   'std': np.float64(2.316786567640619),
#   'avg': np.float64(98.95),
#   'min': np.float64(88.0),
#   'max': np.float64(100.0)},
#  {'gen': 63,
#   'nevals': 187,
#   'std': np.float64(2.3548790957404915),
#   'avg': np.float64(98.82333333333334),
#   'min': np.float64(88.0),
#   'max': np.float64(100.0)},
#  {'gen': 64,
#   'nevals': 184,
#   'std': np.float64(1.9780433654385727),
#   'avg': np.float64(99.10333333333334),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)},
#  {'gen': 65,
#   'nevals': 171,
#   'std': np.float64(2.28680028764113),
#   'avg': np.float64(99.02333333333333),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)},
#  {'gen': 66,
#   'nevals': 200,
#   'std': np.float64(2.2436948693319834),
#   'avg': np.float64(98.95),
#   'min': np.float64(88.0),
#   'max': np.float64(100.0)},
#  {'gen': 67,
#   'nevals': 195,
#   'std': np.float64(2.373639961465653),
#   'avg': np.float64(98.95),
#   'min': np.float64(86.0),
#   'max': np.float64(100.0)},
#  {'gen': 68,
#   'nevals': 175,
#   'std': np.float64(2.195295474924098),
#   'avg': np.float64(98.89666666666666),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)},
#  {'gen': 69,
#   'nevals': 166,
#   'std': np.float64(2.2097636877176607),
#   'avg': np.float64(99.01666666666667),
#   'min': np.float64(89.0),
#   'max': np.float64(100.0)},
#  {'gen': 70,
#   'nevals': 199,
#   'std': np.float64(2.428394531372528),
#   'avg': np.float64(98.77),
#   'min': np.float64(89.0),
#   'max': np.float64(100.0)},
#  {'gen': 71,
#   'nevals': 188,
#   'std': np.float64(2.057989849883187),
#   'avg': np.float64(99.03666666666666),
#   'min': np.float64(91.0),
#   'max': np.float64(100.0)},
#  {'gen': 72,
#   'nevals': 177,
#   'std': np.float64(2.2366120211903837),
#   'avg': np.float64(98.97),
#   'min': np.float64(89.0),
#   'max': np.float64(100.0)},
#  {'gen': 73,
#   'nevals': 186,
#   'std': np.float64(2.3875231237972683),
#   'avg': np.float64(98.92),
#   'min': np.float64(89.0),
#   'max': np.float64(100.0)},
#  {'gen': 74,
#   'nevals': 175,
#   'std': np.float64(2.277181493767143),
#   'avg': np.float64(98.96666666666667),
#   'min': np.float64(88.0),
#   'max': np.float64(100.0)},
#  {'gen': 75,
#   'nevals': 180,
#   'std': np.float64(2.354369460291981),
#   'avg': np.float64(98.91666666666667),
#   'min': np.float64(89.0),
#   'max': np.float64(100.0)},
#  {'gen': 76,
#   'nevals': 187,
#   'std': np.float64(2.1945665226240516),
#   'avg': np.float64(98.85666666666667),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)},
#  {'gen': 77,
#   'nevals': 172,
#   'std': np.float64(2.298006382352611),
#   'avg': np.float64(98.85),
#   'min': np.float64(91.0),
#   'max': np.float64(100.0)},
#  {'gen': 78,
#   'nevals': 220,
#   'std': np.float64(2.2615899028977138),
#   'avg': np.float64(98.87666666666667),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)},
#  {'gen': 79,
#   'nevals': 173,
#   'std': np.float64(2.395391408517614),
#   'avg': np.float64(98.89),
#   'min': np.float64(87.0),
#   'max': np.float64(100.0)},
#  {'gen': 80,
#   'nevals': 179,
#   'std': np.float64(2.3313706030764156),
#   'avg': np.float64(98.89333333333333),
#   'min': np.float64(88.0),
#   'max': np.float64(100.0)},
#  {'gen': 81,
#   'nevals': 190,
#   'std': np.float64(1.9768212418481907),
#   'avg': np.float64(99.21333333333334),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)},
#  {'gen': 82,
#   'nevals': 174,
#   'std': np.float64(2.25757736424592),
#   'avg': np.float64(98.99666666666667),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)},
#  {'gen': 83,
#   'nevals': 171,
#   'std': np.float64(2.1595884381571926),
#   'avg': np.float64(98.94666666666667),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)},
#  {'gen': 84,
#   'nevals': 188,
#   'std': np.float64(2.4526629518862872),
#   'avg': np.float64(98.66666666666667),
#   'min': np.float64(89.0),
#   'max': np.float64(100.0)},
#  {'gen': 85,
#   'nevals': 189,
#   'std': np.float64(2.2711132854958063),
#   'avg': np.float64(98.90666666666667),
#   'min': np.float64(89.0),
#   'max': np.float64(100.0)},
#  {'gen': 86,
#   'nevals': 193,
#   'std': np.float64(2.4776781245530843),
#   'avg': np.float64(98.76666666666667),
#   'min': np.float64(88.0),
#   'max': np.float64(100.0)},
#  {'gen': 87,
#   'nevals': 179,
#   'std': np.float64(2.122919896955344),
#   'avg': np.float64(99.05666666666667),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)},
#  {'gen': 88,
#   'nevals': 178,
#   'std': np.float64(2.3490328979296047),
#   'avg': np.float64(98.90666666666667),
#   'min': np.float64(89.0),
#   'max': np.float64(100.0)},
#  {'gen': 89,
#   'nevals': 183,
#   'std': np.float64(2.3879698490558883),
#   'avg': np.float64(98.76),
#   'min': np.float64(89.0),
#   'max': np.float64(100.0)},
#  {'gen': 90,
#   'nevals': 201,
#   'std': np.float64(2.462708536009354),
#   'avg': np.float64(98.78),
#   'min': np.float64(88.0),
#   'max': np.float64(100.0)},
#  {'gen': 91,
#   'nevals': 170,
#   'std': np.float64(2.0268503206261244),
#   'avg': np.float64(99.12333333333333),
#   'min': np.float64(91.0),
#   'max': np.float64(100.0)},
#  {'gen': 92,
#   'nevals': 173,
#   'std': np.float64(2.1307171458350718),
#   'avg': np.float64(99.00666666666666),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)},
#  {'gen': 93,
#   'nevals': 180,
#   'std': np.float64(2.0733762053445317),
#   'avg': np.float64(99.03333333333333),
#   'min': np.float64(88.0),
#   'max': np.float64(100.0)},
#  {'gen': 94,
#   'nevals': 195,
#   'std': np.float64(2.325938281401484),
#   'avg': np.float64(98.83666666666667),
#   'min': np.float64(87.0),
#   'max': np.float64(100.0)},
#  {'gen': 95,
#   'nevals': 186,
#   'std': np.float64(2.458554227363897),
#   'avg': np.float64(98.95333333333333),
#   'min': np.float64(87.0),
#   'max': np.float64(100.0)},
#  {'gen': 96,
#   'nevals': 166,
#   'std': np.float64(2.1204061455820726),
#   'avg': np.float64(99.02333333333333),
#   'min': np.float64(91.0),
#   'max': np.float64(100.0)},
#  {'gen': 97,
#   'nevals': 177,
#   'std': np.float64(1.8139551629886923),
#   'avg': np.float64(99.23),
#   'min': np.float64(92.0),
#   'max': np.float64(100.0)},
#  {'gen': 98,
#   'nevals': 194,
#   'std': np.float64(2.347821685449444),
#   'avg': np.float64(98.88),
#   'min': np.float64(91.0),
#   'max': np.float64(100.0)},
#  {'gen': 99,
#   'nevals': 174,
#   'std': np.float64(2.0517607614491076),
#   'avg': np.float64(99.18333333333334),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)},
#  {'gen': 100,
#   'nevals': 173,
#   'std': np.float64(2.202211010174396),
#   'avg': np.float64(99.06),
#   'min': np.float64(90.0),
#   'max': np.float64(100.0)}]

# %%
if __name__ == "__main__":
    main()
# Out:
# --- Generation 1 ---
#   Min 40.0
#   Max 66.0
#   Avg 53.47666666666667
#   Std 4.187615338378421
# --- Generation 2 ---
#   Min 46.0
#   Max 68.0
#   Avg 56.473333333333336
#   Std 3.8169737867699447
# --- Generation 3 ---
#   Min 50.0
#   Max 70.0
#   Avg 59.776666666666664
#   Std 3.698664924296634
# --- Generation 4 ---
#   Min 54.0
#   Max 71.0
#   Avg 62.71666666666667
#   Std 3.2129512220940355
# --- Generation 5 ---
#   Min 58.0
#   Max 73.0
#   Avg 65.26333333333334
#   Std 2.814365924245736
# --- Generation 6 ---
#   Min 57.0
#   Max 76.0
#   Avg 67.12333333333333
#   Std 2.6909952723027137
# --- Generation 7 ---
#   Min 60.0
#   Max 76.0
#   Avg 68.91333333333333
#   Std 2.688088953554592
# --- Generation 8 ---
#   Min 58.0
#   Max 77.0
#   Avg 70.53333333333333
#   Std 2.7692758780751494
# --- Generation 9 ---
#   Min 65.0
#   Max 79.0
#   Avg 72.28666666666666
#   Std 2.458554227363897
# --- Generation 10 ---
#   Min 65.0
#   Max 80.0
#   Avg 73.62333333333333
#   Std 2.5089417866680144
# --- Generation 11 ---
#   Min 68.0
#   Max 85.0
#   Avg 75.27
#   Std 2.242862754011786
# --- Generation 12 ---
#   Min 67.0
#   Max 85.0
#   Avg 76.88
#   Std 2.4492720006837407
# --- Generation 13 ---
#   Min 68.0
#   Max 85.0
#   Avg 78.3
#   Std 2.4020824298928627
# --- Generation 14 ---
#   Min 70.0
#   Max 85.0
#   Avg 79.52333333333333
#   Std 2.3358343738848912
# --- Generation 15 ---
#   Min 69.0
#   Max 87.0
#   Avg 80.71666666666667
#   Std 2.4528328293809363
# --- Generation 16 ---
#   Min 69.0
#   Max 90.0
#   Avg 82.07
#   Std 2.361870727481361
# --- Generation 17 ---
#   Min 74.0
#   Max 90.0
#   Avg 83.39333333333333
#   Std 2.4163241136532623
# --- Generation 18 ---
#   Min 76.0
#   Max 91.0
#   Avg 84.49
#   Std 2.458298869814924
# --- Generation 19 ---
#   Min 78.0
#   Max 91.0
#   Avg 85.69666666666667
#   Std 2.550422622930473
# --- Generation 20 ---
#   Min 77.0
#   Max 92.0
#   Avg 86.88
#   Std 2.6010767001378485
# --- Generation 21 ---
#   Min 77.0
#   Max 93.0
#   Avg 87.94666666666667
#   Std 2.427032939390994
# --- Generation 22 ---
#   Min 80.0
#   Max 93.0
#   Avg 88.74333333333334
#   Std 2.377138803033783
# --- Generation 23 ---
#   Min 81.0
#   Max 93.0
#   Avg 89.72
#   Std 2.160617195772233
# --- Generation 24 ---
#   Min 79.0
#   Max 94.0
#   Avg 90.37666666666667
#   Std 2.3554452280242524
# --- Generation 25 ---
#   Min 82.0
#   Max 95.0
#   Avg 91.05333333333333
#   Std 2.3015550298777465
# --- Generation 26 ---
#   Min 80.0
#   Max 96.0
#   Avg 91.89666666666666
#   Std 2.2655364829451665
# --- Generation 27 ---
#   Min 84.0
#   Max 96.0
#   Avg 92.43333333333334
#   Std 2.3704195596748034
# --- Generation 28 ---
#   Min 83.0
#   Max 97.0
#   Avg 92.95333333333333
#   Std 2.2958997268076744
# --- Generation 29 ---
#   Min 83.0
#   Max 97.0
#   Avg 93.58
#   Std 2.27821567606464
# --- Generation 30 ---
#   Min 85.0
#   Max 97.0
#   Avg 94.00333333333333
#   Std 2.459672516594209
# --- Generation 31 ---
#   Min 84.0
#   Max 98.0
#   Avg 94.72666666666667
#   Std 2.314869806754199
# --- Generation 32 ---
#   Min 87.0
#   Max 98.0
#   Avg 95.28
#   Std 2.1729242968865714
# --- Generation 33 ---
#   Min 87.0
#   Max 99.0
#   Avg 95.66333333333333
#   Std 2.4269299307744525
# --- Generation 34 ---
#   Min 87.0
#   Max 99.0
#   Avg 96.18333333333334
#   Std 2.301388469791419
# --- Generation 35 ---
#   Min 88.0
#   Max 100.0
#   Avg 96.84333333333333
#   Std 2.2742300284320893
